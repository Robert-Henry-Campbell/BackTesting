# %%
import pandas as pd

df = pd.read_csv('data_for_futures.csv')
df.head(4)
#df.columns
# Out:
#    Unnamed: 0     date sp_price  sp_dividend  sp_real_price  sp_real_dividend
# 0           7  1871.01     4.44         0.26     114.541036          6.707358
# 1           8  1871.02      4.5         0.26     112.649234          6.508622
# 2           9  1871.03     4.61         0.26     113.717822          6.413587
# 3          10  1871.04     4.74         0.26     121.353738          6.656534

# %%
def simulate_portfolio(df, leverage=1, dividend=False, rebalance_period=1):
    df = df.copy()
    df['portfolio'] = 1.0          # seed

    last_rebalance = 0             # position, not label
    for i in range(1, len(df)):    # start at row 1
        if i - last_rebalance == rebalance_period:
            if not dividend:
                base = df.iloc[last_rebalance, df.columns.get_loc('sp_real_price')]
                curr = df.iloc[i, df.columns.get_loc('sp_real_price')]
                df.iat[i, df.columns.get_loc('portfolio')] = (
                    df.iat[last_rebalance, df.columns.get_loc('portfolio')]
                    + leverage * (curr - base)
                )
            else:
                raise NotImplementedError("Dividend handling not built yet")
            last_rebalance = i
        else:
            # carry portfolio forward unchanged
            df.iat[i, df.columns.get_loc('portfolio')] = df.iat[i-1, df.columns.get_loc('portfolio')]

    return df

onex = simulate_portfolio(df)

# %%
onex.head()
# Out:
#    Unnamed: 0     date sp_price  sp_dividend  sp_real_price  sp_real_dividend  \
# 0           7  1871.01     4.44         0.26     114.541036          6.707358
# 1           8  1871.02      4.5         0.26     112.649234          6.508622
# 2           9  1871.03     4.61         0.26     113.717822          6.413587
# 3          10  1871.04     4.74         0.26     121.353738          6.656534
# 4          11  1871.05     4.86         0.26     127.319383          6.811325
#
#    portfolio
# 0   1.000000
# 1  -0.891803
# 2   0.176786
# 3   7.812702
# 4  13.778347
